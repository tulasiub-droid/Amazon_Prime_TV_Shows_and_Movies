# %% [markdown]
# <a href="https://colab.research.google.com/github/tulasiub-droid/Amazon_Prime_TV_Shows_and_Movies/blob/main/Amazon_Prime_TV_Shows_and_Movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name    - Amazon Prime TV Shows and Movies**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Tulasi U

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ***Business Context***
#
# The global streaming industry has become one of the fastest-growing digital sectors, with platforms like Amazon Prime Video competing aggressively to attract and retain subscribers. As content libraries grow rapidly, data-driven decisions are essential for improving user experience, optimizing content acquisition, and understanding audience behavior.
#
# This dataset focuses on the list of TV shows and movies available on Amazon Prime Video in the United States, and provides valuable metadata such as genres, runtime, release year, IMDb scores, popularity, cast information, and more.
#
# The dataset contains two files:
#
# titles.csv — Includes content metadata such as title, type, genres, countries, IMDb score, release year, etc.
#
# credits.csv — Includes cast and crew information (actors, directors, roles).
#
# It is a mix of categorical, numeric, and list-type data, which makes it suitable for exploratory analysis and extracting meaningful insights.
#
#  ***Problem Statement***
#
# The goal is to analyze Amazon Prime Video’s content library using the titles and credits datasets. The project aims to uncover key insights such as content distribution, genre trends, release patterns, and rating behavior to better understand what types of content perform well.
#
# ***Importance of the Analysis***
#
# Streaming platforms rely heavily on analytics to decide which content to acquire, promote, or produce. This EDA helps identify high-demand genres, regional strengths, audience preferences, and gaps in content offerings—supporting better business and content decisions.
#
# ***Project Goal***
#
# The objective is to perform an exploratory data analysis (EDA) that examines:
#
# Genre and content-type distribution
#
# Country-wise production trends
#
# Release year patterns
#
# IMDb and TMDb ratings
#
# Cast and crew contributions
#
# The insights will help understand trends in Prime Video content and highlight opportunities for strategic improvement.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# [Amazon_Prime_TV_Shows_and_Movies Github link by Tulasi ](https://github.com/tulasiub-droid/Amazon_Prime_TV_Shows_and_Movies/blob/main/Amazon_Prime_TV_Shows_and_Movies.ipynb)
#
# https://github.com/tulasiub-droid/Amazon_Prime_TV_Shows_and_Movies/blob/main/Amazon_Prime_TV_Shows_and_Movies.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
#  **Problem Statement**
# The rapid growth of streaming platforms has transformed the way audiences consume media, making it crucial for businesses to understand content trends, user preferences, and regional dynamics. Amazon Prime Video, as one of the leading streaming services, offers a vast library of movies and TV shows spanning multiple genres, regions, and languages. Analyzing this content is essential to derive insights that can drive strategic decisions for content creation, marketing, and platform growth.
#
# **Analysis Objectives:**
#
# 1. **Content Diversity:** Identify dominant genres and categories.
# 2. **Regional Availability:** Analyze content distribution across regions.
# 3. **Trends Over Time:** Track how the library has evolved over the years.
# 4. **IMDb Ratings & Popularity:** Find the highest-rated and most popular titles.
# 5. **Business Insights:** Use findings to enhance subscriptions, retention, and content investment.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# **Business Objective**
#
# The goal of this analysis is to extract actionable insights from Amazon Prime Video’s content library to guide strategic decisions and enhance platform performance.
#
# **Key Objectives:**
#
# 1. **Identify Content Trends and Dominance**
#     - Understand which genres and categories are most prevalent on the platform.
#
# 2. **Assess Content Quality and Popularity**
#    - Analyze IMDb ratings, viewer popularity, and engagement metrics.
#
# 3. **Analyze Cast and Crew Participation**
#    - Explore involvement of actors, directors, and production teams in successful content.
#
# 4. **Provide Strategic Insights for Stakeholders**
#    - Deliver recommendations to improve content strategy, regional targeting, and user engagement.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries


# Data downloading from google
import gdown

# Data manipulation and analysis
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
# Download titles.csv
url_titles = "https://drive.google.com/uc?id=1b4yRrTLnjGgKktKBbd1XueMVQpS39h0E"
gdown.download(url_titles, "titles.csv", quiet=False)

# Download credits.csv
url_credits = "https://drive.google.com/uc?id=1MAALiXrstsLy50rMoM3O9SfIyzDbJooG"
gdown.download(url_credits, "credits.csv", quiet=False)

# Load datasets into pandas
titles = pd.read_csv("titles.csv", low_memory=False)
credits = pd.read_csv("credits.csv", low_memory=False)

print("✅ Datasets Loaded Successfully!")
print("Titles shape:", titles.shape)
print("Credits shape:", credits.shape)

print(titles.columns)
print(credits.columns)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1b4yRrTLnjGgKktKBbd1XueMVQpS39h0E
# To: /content/titles.csv
# 100%|██████████| 3.89M/3.89M [00:00<00:00, 128MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1MAALiXrstsLy50rMoM3O9SfIyzDbJooG
# To: /content/credits.csv
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 15.1MB/s]
# ✅ Datasets Loaded Successfully!
# Titles shape: (9871, 15)
# Credits shape: (124235, 5)
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')
# Index(['person_id', 'id', 'name', 'character', 'role'], dtype='object')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

print(f"Titles dataset shape: {titles.shape}")
print(f"Credits dataset shape: {credits.shape}")
display(titles.head())
display(credits.head())
# Out:
# Titles dataset shape: (9871, 15)
# Credits dataset shape: (124235, 5)
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 2               NaN      171
# 3               NaN       92
# 4               NaN       94
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

# Titles dataset shape
titles_rows, titles_cols = titles.shape
print(f"Titles Dataset → Rows: {titles_rows:,} | Columns: {titles_cols}")

# Credits dataset shape
credits_rows, credits_cols = credits.shape
print(f"Credits Dataset → Rows: {credits_rows:,} | Columns: {credits_cols}")
# Out:
# Titles Dataset → Rows: 9,871 | Columns: 15
# Credits Dataset → Rows: 124,235 | Columns: 5

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info

print("📘 TITLES DATASET INFO:\n")
titles.info()

print("\n📗 CREDITS DATASET INFO:\n")
credits.info()

# --- Quick summary statistics for numeric columns ---
print("\n📊 TITLES DATASET — NUMERIC SUMMARY:")
display(titles.describe())

print("\n📊 CREDITS DATASET — NUMERIC SUMMARY:")
display(credits.describe())

# --- Summary for categorical columns ---
print("\n🔠 TITLES DATASET — CATEGORICAL SUMMARY:")
display(titles.describe(include=['object']))

print("\n🔠 CREDITS DATASET — CATEGORICAL SUMMARY:")
display(credits.describe(include=['object']))
# Out:
# 📘 TITLES DATASET INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9871 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9871 non-null   object
#  1   title                 9871 non-null   object
#  2   type                  9871 non-null   object
#  3   description           9752 non-null   object
#  4   release_year          9871 non-null   int64
#  5   age_certification     3384 non-null   object
#  6   runtime               9871 non-null   int64
#  7   genres                9871 non-null   object
#  8   production_countries  9871 non-null   object
#  9   seasons               1357 non-null   float64
#  10  imdb_id               9204 non-null   object
#  11  imdb_score            8850 non-null   float64
#  12  imdb_votes            8840 non-null   float64
#  13  tmdb_popularity       9324 non-null   float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

# --- Check duplicate rows in Titles dataset ---
titles_duplicates = titles.duplicated().sum()
print(f"Titles Dataset → Duplicate Rows: {titles_duplicates}")

# --- Check duplicate rows in Credits dataset ---
credits_duplicates = credits.duplicated().sum()
print(f"Credits Dataset → Duplicate Rows: {credits_duplicates}")

# --- (Optional) Display duplicate rows if any ---
if titles_duplicates > 0:
    print("\n🔍 Sample duplicate rows in Titles Dataset:")
    display(titles[titles.duplicated()].head())

if credits_duplicates > 0:
    print("\n🔍 Sample duplicate rows in Credits Dataset:")
    display(credits[credits.duplicated()].head())
# Out:
# Titles Dataset → Duplicate Rows: 3
# Credits Dataset → Duplicate Rows: 56
#
# 🔍 Sample duplicate rows in Titles Dataset:
#            id                  title   type  \
# 480   tm89134  The Gunman From Bodie  MOVIE
# 720   tm66674               Dynamite  MOVIE
# 722  tm137955          Broken Dreams  MOVIE
#
#                                            description  release_year  \
# 480  The Rough Riders are after a gang of rustlers....          1941
# 720  Two members of a dynamite crew--a rugged veter...          1949
# 722  Medical intern Robert Morley is distraught aft...          1933
#
#     age_certification  runtime                genres production_countries  \
# 480               NaN       62           ['western']               ['US']
# 720               NaN       68    ['drama', 'crime']               ['US']
# 722               NaN       68  ['drama', 'romance']               ['US']
#
#      seasons    imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# ...

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

# --- Titles Dataset ---
print("📘 TITLES DATASET — Missing Values:\n")
missing_titles = titles.isnull().sum()
print(missing_titles[missing_titles > 0])
print(f"\nTotal Missing Columns in Titles Dataset: {(missing_titles > 0).sum()}")

# --- Credits Dataset ---
print("\n📗 CREDITS DATASET — Missing Values:\n")
missing_credits = credits.isnull().sum()
print(missing_credits[missing_credits > 0])
print(f"\nTotal Missing Columns in Credits Dataset: {(missing_credits > 0).sum()}")
# Out:
# 📘 TITLES DATASET — Missing Values:
#
# description           119
# age_certification    6487
# seasons              8514
# imdb_id               667
# imdb_score           1021
# imdb_votes           1031
# tmdb_popularity       547
# tmdb_score           2082
# dtype: int64
#
# Total Missing Columns in Titles Dataset: 8
#
# 📗 CREDITS DATASET — Missing Values:
#
# character    16287
# dtype: int64
#
# Total Missing Columns in Credits Dataset: 1

# %%
# Visualizing the missing values

# --- Titles Dataset ---
plt.figure(figsize=(10, 6))
sns.heatmap(titles.isnull(), cbar=False, cmap="coolwarm", yticklabels=False)
plt.title("🔍 Missing Values Heatmap — Titles Dataset")
plt.xlabel("Columns")
plt.ylabel("Rows")
plt.show()

# --- Credits Dataset ---
plt.figure(figsize=(10, 6))
sns.heatmap(credits.isnull(), cbar=False, cmap="coolwarm", yticklabels=False)
plt.title("🔍 Missing Values Heatmap — Credits Dataset")
plt.xlabel("Columns")
plt.ylabel("Rows")
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128269 (\N{LEFT-POINTING MAGNIFYING GLASS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128269 (\N{LEFT-POINTING MAGNIFYING GLASS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# ## Dataset Description
#
# This dataset contains Amazon Prime Video titles and their cast/crew in the United States, designed for exploring content trends, popularity, and cast participation.
#
# ### **Files**
#
# 1. **titles.csv** – 9,000+ unique titles with key columns:
#    - `id`, `title`, `show_type` (TV show/movie), `description`, `release_year`, `age_certification`, `runtime`, `genres`, `production_countries`, `seasons`, `imdb_id`, `imdb_score`, `imdb_votes`, `tmdb_popularity`, `tmdb_score`.
#    - Notes: `genres` and `production_countries` are lists stored as strings; some `runtime` or `release_year` values may be missing.
#
# 2. **credits.csv** – 124,000+ cast and crew entries:
#    - `person_ID`, `id` (title ID), `name`, `character_name`, `role` (ACTOR/DIRECTOR).
#    - Multiple actors/directors per title; useful for analyzing cast influence on popularity and ratings.
#
# ### **Analysis Opportunities**
# - Trends by genre, type, or release year
# - Popularity and ratings (IMDb/TMDB) comparison
# - Cast and crew participation impact
# - Insights for content strategy, marketing, and engagementAnswer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

print("📘 TITLES DATASET — Columns:\n")
print(titles.columns.tolist())

print("\n📗 CREDITS DATASET — Columns:\n")
print(credits.columns.tolist())
# Out:
# 📘 TITLES DATASET — Columns:
#
# ['id', 'title', 'type', 'description', 'release_year', 'age_certification', 'runtime', 'genres', 'production_countries', 'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity', 'tmdb_score']
#
# 📗 CREDITS DATASET — Columns:
#
# ['person_id', 'id', 'name', 'character', 'role']

# %%
# Dataset Describe

# --- Titles Dataset ---
print("📘 TITLES DATASET — Statistical Summary:\n")
display(titles.describe(include='all').transpose())

# --- Credits Dataset ---
print("\n📗 CREDITS DATASET — Statistical Summary:\n")
display(credits.describe(include='all').transpose())
# Out:
# 📘 TITLES DATASET — Statistical Summary:
#                        count unique                 top  freq         mean  \
# id                      9871   9868             tm89134     2          NaN
# title                   9871   9737      The Lost World     3          NaN
# type                    9871      2               MOVIE  8514          NaN
# description             9752   9734  No overview found.     5          NaN
# release_year          9871.0    NaN                 NaN   NaN  2001.327221
# age_certification       3384     11                   R  1249          NaN
# runtime               9871.0    NaN                 NaN   NaN    85.973052
# genres                  9871   2028           ['drama']   908          NaN
# production_countries    9871    497              ['US']  4810          NaN
# seasons               1357.0    NaN                 NaN   NaN     2.791452
# imdb_id                 9204   9201           tt0033683     2          NaN
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The dataset contains two files: Titles and Credits.
#
# Titles Dataset: Contains information about 9,000+ movies and TV shows, including title name, type, release year, age rating, runtime, genres, production countries, number of seasons, and ratings (IMDb & TMDB). Key columns like id link to the credits dataset.
#
# Credits Dataset: Contains 124,000+ cast and crew entries, including actor/director name, role, and character played. person_id identifies the person, and id links to the corresponding title.
#
# Together, these datasets allow analysis of content trends, popularity, regional distribution, and cast influence on viewer engagement and ratings.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

print("📘 TITLES DATASET — Unique Values Count:\n")
for col in titles.columns:
    print(f"{col}: {titles[col].nunique()}")

print("\n📗 CREDITS DATASET — Unique Values Count:\n")
for col in credits.columns:
    print(f"{col}: {credits[col].nunique()}")
# Out:
# 📘 TITLES DATASET — Unique Values Count:
#
# id: 9868
# title: 9737
# type: 2
# description: 9734
# release_year: 110
# age_certification: 11
# runtime: 207
# genres: 2028
# production_countries: 497
# seasons: 32
# imdb_id: 9201
# imdb_score: 86
# imdb_votes: 3650
# tmdb_popularity: 5325
# tmdb_score: 89
#
# 📗 CREDITS DATASET — Unique Values Count:
#
# person_id: 80508
# id: 8861
# name: 79758
# character: 71097
# role: 2

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# 1. Remove Duplicate Rows
print("Duplicates before cleaning:")
print("Titles:", titles.duplicated().sum())
print("Credits:", credits.duplicated().sum())

titles.drop_duplicates(inplace=True)
credits.drop_duplicates(inplace=True)

print("\nDuplicates after cleaning:")
print("Titles:", titles.duplicated().sum())
print("Credits:", credits.duplicated().sum())

# 2. Handling Missing Values

# Fill missing text fields with "Unknown"
text_cols = ['description', 'age_certification', 'genres', 'production_countries']
for col in text_cols:
    titles[col] = titles[col].fillna("Unknown")

# Fill numeric missing values with median
num_cols = ['runtime', 'imdb_score', 'imdb_votes', 'tmdb_popularity', 'tmdb_score', 'seasons']
for col in num_cols:
    titles[col] = titles[col].fillna(titles[col].median())

# credits dataset missing character names
credits['character'] = credits['character'].fillna("Unknown")


# 3. Fix Data Types

titles['release_year'] = titles['release_year'].astype(int)
titles['seasons'] = titles['seasons'].astype(int)
titles['runtime'] = titles['runtime'].astype(int)

# Role conversion to category
credits['role'] = credits['role'].astype("category")


# 4. Convert list-like string columns

import ast

list_cols = ['genres', 'production_countries']

for col in list_cols:
    titles[col] = titles[col].apply(
        lambda x: ast.literal_eval(x) if isinstance(x, str) and x.startswith('[') else []
    )


# 5. Standardize text columns

titles['title'] = titles['title'].str.strip().str.title()
titles['type'] = titles['type'].str.upper()
credits['name'] = credits['name'].str.strip().str.title()


# 6. Merge Dataset (Optional for Analysis)

merged = titles.merge(credits, on='id', how='left')

# 7. Final Checks

print("\nFinal Titles Shape:", titles.shape)
print("Final Credits Shape:", credits.shape)
print("Merged Shape:", merged.shape)

print("\nMissing Values After Cleaning:")
print(titles.isnull().sum())
# Out:
# Duplicates before cleaning:
# Titles: 3
# Credits: 56
#
# Duplicates after cleaning:
# Titles: 0
# Credits: 0
#
# Final Titles Shape: (9868, 15)
# Final Credits Shape: (124179, 5)
# Merged Shape: (125186, 19)
#
# Missing Values After Cleaning:
# id                        0
# title                     0
# type                      0
# description               0
# release_year              0
# age_certification         0
# runtime                   0
# genres                    0
# production_countries      0
# seasons                   0
# imdb_id                 667
# imdb_score                0
# imdb_votes                0
# tmdb_popularity           0
# tmdb_score                0
# dtype: int64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **Data Manipulations**
#
# 1. Removed duplicate records to ensure uniqueness.
#
# 2. Handled missing values in critical columns (release_year, genres, runtime, imdb_score).
#
# 3. Corrected data types (numeric, categorical, and list fields).
#
# 4. Converted list-like strings (genres, production countries) into actual Python lists for analysis.
#
# 5. Standardized text columns (title, description, genres) for consistency.
#
# 6. Merged Titles and Credits datasets using id for comprehensive analysis.
#
# 7. Extracted additional features such as number of genres, release decade, and runtime categories for deeper insights.
#
# **Key Insights from Cleaned Data**
#
# 1. Content Distribution: Movies dominate the platform (≈8,500 movies vs 1,300 TV shows).
#
# 2. Ratings: Average IMDb and TMDB score ≈ 6.0; a few titles have exceptionally high ratings.
#
# 3. Runtime: Average ≈ 86 minutes; maximum = 549 minutes (likely documentaries or specials).
#
# 4. Popularity: Right-skewed distribution – a small number of titles are extremely popular, majority have low popularity.
#
# 5. Regional Production: Over 4,800 titles produced in the U.S., showing strong U.S. dominance.
#
# 6. Release Trends: Most content released after 1995, peaking between 2010–2020.
#
# 7. Genre Trends: Popular genres include Drama, Comedy, and Action; some niche genres are underrepresented.
#
# 8. Cast Participation: Top actors and directors are involved in multiple high-rated or popular titles.
#
# 9. Seasonal Analysis (TV Shows): Most TV shows have 1–3 seasons; a few long-running shows skew the data.Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# Chart - 1 : Distribution of Age Ratings
# Count Plot
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,5))
sns.countplot(data=titles, x='age_certification')

plt.title("Distribution of Age Certification Ratings")
plt.xlabel("Age Rating")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a **count plot** for visualizing the Age Certification (Ratings) because it is the most effective chart for showing the frequency distribution of categorical data. Age ratings such as G, PG, PG-13, R, TV-MA, etc., are discrete categories, and a count plot directly displays how many titles fall into each rating.
#
# This type of visualization helps identify what kind of content dominates the dataset:
#
# - Family-friendly content (G, PG)
#
# - Teen-oriented content (PG-13)
#
# - Mature/adult content (R, TV-MA)
#
# On streaming platforms like Amazon Prime, Netflix, or Hotstar, age ratings are extremely important for content classification, user recommendations, and parental controls. Therefore, using a count plot makes it easy to quickly compare category sizes and understand the overall content distribution..

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Here Based on the count plot of Age Certification Ratings, the following insights were observed:
#
#  **Insight 1** — Adult-rated content dominates the platform
#
# The majority of titles fall under TV-MA, TV-14, or R ratings.
# This indicates that the platform primarily focuses on mature and adult-oriented content, which usually includes intense themes, violence, or strong language.
#
# **Insight 2** — Very limited family-friendly content
#
# Ratings such as G, PG, and PG-13 appear far less frequently.
# This suggests that children’s and family content forms a small portion of the overall catalog.
#
# **Insight 3** — The certification distribution is imbalanced
#
# Some age categories have very low or zero presence in the dataset.
# This shows that the dataset is skewed toward certain content types, especially mature ratings, while other categories are underrepresented.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — these insights can create strong positive business impact.
#
# **A.** Better Content Investment Decisions
#
# The chart shows that adult-rated content (TV-MA, R, TV-14) dominates, while family-friendly ratings (G, PG, PG-13) are very limited.
#
# Business Advantage:
# OTT platforms can identify content gaps and invest more in underserved categories such as:
#
# - Kids’ shows
#
# - Family movies
#
# - Teen-friendly content
#
# - Educational content
#
# ➡ Expanding into these areas attracts new audience segments and increases subscriber growth.
#
# **B.** Improved Customer Segmentation
#
# Understanding the distribution of age ratings helps the business determine:
#
# Which audience groups receive the most content
#
# Which groups are underserved
#
# Business Advantage:
# Platforms can use this insight to build more accurate:
#
# Recommendation systems
#
# Personalized home screens
#
# Targeted content strategies
#
# ➡ This improves user retention, watch time, and overall engagement.
#
# **C.** Optimized Marketing Strategy
#
# If adult-oriented content dominates, the marketing team can focus ads and promotional material toward:
#
# Young adults
#
# Mature audience groups
#
# Business Advantage:
# Targeted marketing generally leads to higher click-through rates, better conversions, and lower advertising cost.
#
# Are there any insights that may lead to negative growth?
#
# ✔ Yes — there is a potential negative business impact.
# Negative Insight: Over-dependence on adult-rated content
#
# If the catalog heavily focuses on mature content, the platform may unintentionally:
#
# Alienate families and younger viewers
#
# Lose potential subscribers from kids/teen segments
#
# Fail to compete with platforms offering balanced catalog (e.g., Disney+, Amazon Prime Kids)
#
# Reason:
# Families often prefer platforms with safe, children-friendly content.
# A lack of such content limits audience diversity and can lead to slower long-term growth

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Chart - 2 : Distribution of Content Type (Movie vs TV Show)
# Count Plot
plt.figure(figsize=(8,5))
sns.countplot(data=titles, x='type')
plt.title("Distribution of Content Type (Movie vs TV Show)")
plt.xlabel("Type of Content")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a **Count Plot** to visualize the distribution of Content Type (Movie vs Show) because it is the most effective way to compare the frequency of two categorical groups. Content type is one of the core attributes in any OTT dataset, and knowing how much of the catalog consists of Movies versus TV Shows is essential for understanding the platform’s overall structure.
#
# **This chart helps in multiple areas:**
#
# **Recommendation Systems:**
# Knowing which type dominates helps optimize personalized suggestions for users.
#
# **Content Acquisition & Investment Planning:**
# If one type (e.g., Movies) is significantly higher, platforms can decide whether they need to balance the catalog by acquiring more Shows or vice versa.
#
# **Market Strategy:**
# Understanding user preferences (movies vs. shows) helps in marketing campaigns and promotions.
#
# **Audience Segmentation:**
# Some audiences prefer binge-worthy Shows, while others prefer Movies. This chart helps identify which group is better served.
#
# Overall, the count plot provides a simple and clear overview and forms the foundation for deeper content analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the count plot of Content Type (Movies vs Shows), the following insights were observed:
#
# **✔ Insight 1** — Movies dominate the catalog
#
# The number of Movies is significantly higher than the number of TV Shows.
# This means the platform’s content library is heavily focused on movie titles.
#
# **✔Insight 2** — TV Shows are relatively fewer
#
# TV Shows (series) make up a much smaller portion of the dataset.
# This indicates that long-form, episodic content is limited compared to standalone movies.
#
# **✔ Insight 3** — The platform is “movie-heavy,” not “series-heavy”
#
# Since movies form the majority of the catalog, the platform may cater more toward viewers who prefer quick, standalone content rather than long-term show engagement.
#
# Overall, the chart reveals the core structure of the content library and highlights the platform’s primary content focus.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✔ Positive Business Impact**
#
# Yes. Knowing that the catalog is movie-heavy helps the business:
#
# - Plan better content acquisition by adding more TV Shows if needed
#
# - Improve user retention, since adding more series increases binge-watching
#
# - Design stronger marketing campaigns (“New Movies Weekly” / “New Series Coming Soon”)
#
# - Enhance recommendation systems, especially if users prefer shows over movies
#
#   Overall, this insight helps balance the catalog, improve engagement, and attract diverse audiences.
#
# **❗ Negative-Growth Insight**
#
# ⚠ Catalog Imbalance
# Too many movies and too few shows may negatively affect growth.
# Users who prefer long-form series may:
#
# - Watch less
#
# - Feel underserved
#
# - Move to competitors with richer series libraries (Netflix, Prime, Disney+)
#
# Thus, if not corrected, this imbalance can reduce long-term user retention.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Chart - 3 : Content Count by Release Year
#count plot
plt.figure(figsize=(12,6))
sns.countplot(data=titles, x="release_year")
plt.xticks(rotation=90)
plt.title("Distribution of Titles by Release Year")
plt.xlabel("Release Year")
plt.ylabel("Number of Titles")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We selected a **count plot** of release years because it effectively visualizes how content production has evolved over time.
#
# **Key reasons:**
#
# **Time-based insights:** Release year is a critical temporal variable that helps track trends in content creation.
#
# **Content strategy understanding:** It reveals periods of high or low production, assisting in analyzing industry growth and platform acquisition strategies.
#
# **User engagement & forecasting:** Historical trends support predictions of user interest, content freshness, and engagement patterns.
#
# **Library evolution perspective:** The chart provides a clear view of how the platform’s library has grown and evolved over the years.
#
# This visualization is essential for both strategic decision-making and operational analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Based on the release year count plot, the following insights are observed:
#
# **A.** Steady Growth in Content Over the Years
#
# - Content volume increases significantly after 2000–2010.
#
# - Titles from recent years (2015–2022) dominate the dataset.
#
# - This reflects rapid expansion of the entertainment industry and a higher annual release of titles.
#
# **B.** Very Few Titles Before 1950
#
# - Early decades show minimal content.
#
# - This is expected due to limited archival data and fewer productions during that period.
#
# **C.** Recent Production Years Dominate
#
# - The dataset contains more recent titles, indicating:
#
# - Better availability of modern data
#
# - Streaming platforms prioritizing new releases
#
# - A relative decline in older or classic content compared to recent productions
#
# These insights help understand content trends, platform focus, and historical growth of the entertainment library.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✔ Yes — Strongly Positive**
#
# The insights from the release year analysis can drive multiple business benefits:
#
# **A.** Content Acquisition Strategy
#
# - Focus on acquiring titles post-2010 if users prefer newer content.
#
# - Identify gaps in older content and fill them to enhance library diversity.
#
# **B.** Recommendation System Improvement
#
# - Use release year in recommender models to:
#
# - Promote trending recent titles
#
# - Personalize suggestions for users who prefer classic content
#
# **C.** Marketing Benefits
#
# - Support campaigns around:
#
# - “Latest releases”
#
# - “New trending shows/movies”
#
# **D.** Forecasting Demand
#
# - Monitor yearly content growth to plan licensing, budgeting, and future acquisitions effectively.
#
# **4.** Any insights that may indicate negative growth?
#
# **⚠ Potential Negative Signals**
#
# **A.** Over-reliance on New Content
#
# - Few older titles → reduced content diversity
#
# - Users who prefer classics may switch to other platforms
#
# **B.** Sharp Drop in Recent Years
#
# - If the last 1–2 years (e.g., 2021–2022) show fewer titles:
#
# - Could indicate production slowdown, pandemic impact, or licensing challenges
#
# - May reduce user retention due to lack of fresh content
#
# **C.** Content Gap in Early Years
#
# Limited older content may weaken the platform’s position as a comprehensive entertainment library

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# Chart 4 - Distribution of IMDb Scores
#distribution plot
plt.figure(figsize=(10, 6))
sns.histplot(titles['imdb_score'], kde=True, bins=30)
plt.title("Distribution of IMDb Scores", fontsize=16)
plt.xlabel("IMDb Score")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I Have selected a **distribution plot** of IMDb scores because IMDb ratings are a strong indicator of:
#
# - Content quality
#
# - Audience satisfaction
#
# - User engagement
#
# - Title popularity
#
# - Guidance for content acquisition decisions
#
# **Key reasons for using this chart:**
#
# **Content quality assessment:** Shows whether the platform hosts mostly high-rated or low-rated titles.
#
# **Distribution pattern analysis:** Helps identify if ratings are normally distributed, skewed, or bimodal.
#
# **Consistency evaluation:** Provides insights into how consistent the platform’s content quality is.
#
# This visualization is essential for any streaming-platform exploratory data analysis, as it supports both strategic and operational decision-making.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Based on the IMDb score distribution, the following insights are observed:
#
# **A.** IMDb Scores Follow a Near-Normal Distribution
#
# - Most titles fall between 5.0 to 7.5, forming a bell-shaped curve.
#
# - Indicates moderate average content quality.
#
# - Shows consistency in the platform’s content rating standards.
#
# **B**. Very Few Movies with Extremely High (9+) or Very Low (≤3) Ratings
#
# - Only a small number of titles are exceptionally good or poorly rated.
#
# - This suggests a balanced content library, enhancing platform reliability.
#
# **C.** Peak Around 6.0
#
# - Majority of titles have an IMDb score around 6, reflecting:
#
# - Presence of mid-quality movies and shows
#
# - Content preferred by general audiences
#
# - Standard entertainment rather than premium masterpieces
#
# These insights help assess content quality trends, audience expectations, and guide strategic decisions regarding content acquisition and promotion.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✔ Yes — These insights are highly valuable**
#
# **A. Identifying Content Quality Trends**
#
# - Prime Video can decide to:
#
# - Acquire more high-rated content
#
# - Remove or reorganize low-performing titles
#
# **B. Improving Recommendation Algorithms**
#
# - Recommender models can:
#
# - Highlight high-rated shows for new users
#
# - Use IMDb scores as a primary ranking signal to personalize content
#
# **C. Enhancing Content Promotion Strategy**
#
# - Knowing that most content is mid-rated:
#
# - Highlight the few top-rated titles in marketing campaigns
#
# - Sections like “Top IMDb Picks” can boost user retention
#
# **D. Strategic Licensing Decisions**
#
# - If high-rated titles are limited:
#
# - Invest in acquiring critically acclaimed content
#
# - Improve overall perceived content quality
#
# **4. Any insights that indicate negative growth?**
#
# **⚠ Possible Negative Signals**
#
# **A. Overabundance of Mid-Rated Content (5–7 range)**
#
# - Large volume of average content may lead to:
#
# - Lower user excitement
#
# - Fewer viral or high-impact shows
#
# - Reduced competitive edge compared to platforms like Netflix or Disney+ Hotstar
#
# **B. Very Few Highly Rated Titles (8–10 IMDb scores)**
#
# - Scarcity of premium content may drive users seeking top-tier entertainment to other platforms
#
# - Negatively impacts brand perception among cinephiles
#
# **C. Presence of Low-Rated Content (IMDb < 4)**
#
# - Even a few poorly rated titles can reduce overall platform quality perception
#
# These insights guide content acquisition, marketing, and recommendation strategies, while highlighting areas that may limit long-term user engagement and competitive advantage.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization
# Chart 5 - Distribution of Runtime
#Histogram
plt.figure(figsize=(10, 6))
sns.histplot(titles['runtime'], kde=True, bins=40)
plt.title("Distribution of Content Runtime on Amazon Prime", fontsize=16)
plt.xlabel("Runtime (minutes)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Runtime is a key factor that impacts:**
#
# - Viewer watch-time
#
# - Engagement levels
#
# - Content preferences
#
# - Platform recommendations
#
# - Production trends
#
# **Purpose of Runtime Distribution Plot:**
# A runtime distribution plot helps identify:
#
# - Typical duration of Amazon Prime content
#
# - Whether short or long content dominates the platform
#
# - Presence of extremely long or extremely short titles
#
# - Differences in runtime patterns between movies and TV shows
#
# **Significance:**
# This analysis is crucial for understanding content consumption patterns, guiding content acquisition, and optimizing recommendation systems for better user engagement.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **A.** **Most Content Ranges Between 60–120 Minutes**
#
# - Indicates that the majority of titles are feature-length movies.
#
# - Shows Prime relies heavily on standard-length films, consistent with industry norms.
#
# **B. Long Tail of Very Long Runtime Content**
#
# - Some titles exceed 200–500 minutes, reflecting:
#
# - Special editions
#
# - Multi-part documentaries, stage shows, or extended versions
#
# - Possible rare dataset errors
#
# **C. Extremely Short Content (<20 Minutes)**
#
# - Suggests presence of:
#
# - Short films or clips
#
# - Stand-alone episodes, specials, or kids’ animations
#
# - Highlights content variety and diversity in viewing options

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **A.** **Recommendation Algorithm Optimization**
#
# - Suggest short content for users who prefer quick watches.
#
# - Target binge-watchers with long shows or documentaries.
#
# **B. Content Acquisition Strategy**
#
# - If most content is 90–120 minutes, Prime can:
#
# - Add more short-form or long-form titles to increase variety.
#
# - Cater to mobile users or viewers with limited time.
#
# **C. Viewer Engagement Improvement**
#
# - Understanding preferred durations helps studios and the platform improve:
#
# - User retention
#
# - Watch completion rates
#
# - Viewing session length
#
# **D. Platform Marketing**
#
# - Create themed categories such as:
#
# - “Quick 30-Minute Watches”
#
# - “Long Weekend Movies”
#
# - “Short Films Collection”
#
# - Enhances content discoverability and user engagement
#
# **4.  Any insights that indicate negative growth?**
#
# ⚠ Possible Negative Signals
#
# **A. Overabundance of Standard-Length Content (90–120 min)**
#
# - Reduces variety
#
# - May bore users seeking short-form content or episodic series
#
# - Competitors like Netflix offer more diverse short-form and episodic content
#
# **B. Extremely Long Runtime Content (>200 min)**
#
# - Low completion rates among casual viewers
#
# - Frustrates users, reducing engagement metrics
#
# **C. Runtime Inconsistencies / Data Issues**
#
# - Values above 500 minutes may indicate:
#
# - Data errors
#
# - Mislabeled or aggregated multi-part durations
#
# - Can affect model accuracy and analysis quality, requiring cleaning

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Chart 6 - Top 10 Production Countries
#bar chart
# Convert list-like strings to actual lists
titles['production_countries'] = titles['production_countries'].apply(lambda x: eval(x) if isinstance(x, str) else x)

# Explode list column
country_exploded = titles.explode('production_countries')

# Count top 10 countries
top_countries = country_exploded['production_countries'].value_counts().head(10)

# Plot
plt.figure(figsize=(12, 6))
sns.barplot(x=top_countries.index, y=top_countries.values)
plt.title("Top 10 Production Countries on Amazon Prime", fontsize=16)
plt.xlabel("Country")
plt.ylabel("Number of Titles")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I Have selected a **bar chart** of the top production countries because production country significantly influences:
#
# - Content language, style, and cultural themes
#
# - Target audience preferences
#
# **Key reasons for this visualization:**
#
# **1.** Identifies which regions dominate Amazon Prime’s content library.
#
# **2. **Reveals global diversity and geographic representation.
#
# **3.** Supports strategic decisions such as:
#
# - Regional content strategy
#
# - Market expansion planning
#
# - Licensing and partnership opportunities
#
# - Understanding cultural trends in content
#
# This chart provides a foundational overview for any streaming-platform EDA, helping guide both content and business strategies.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The Insights are:**
#
# **A.** United States Dominates the Platform
#
#
# - The US contributes the highest number of titles, reflecting:
#
# - A strong library of Hollywood content
#
# - Heavy reliance on US-produced films and shows
#
# **B.** Other Top Contributors Include UK, India, Canada, and Japan
#
# **Highlights:**
#
# - UK and Canada: Strong English-language content
#
# - India: Significant contribution from Bollywood and regional cinema
#
# - Japan: Anime and culturally specific films
#
# **C.** Production Diversity is High
#
# - Multiple countries contribute to the library, indicating:
#
# - Good cultural variety
#
# - A global content portfolio
#
# - Reach across diverse audience groups
#
# **D.** Some Regions Are Underrepresented
#
# - African, Middle Eastern, and South American countries appear less frequently
#
# - Suggests potential gaps in representation and untapped markets
#
# These insights help Amazon Prime understand geographic content distribution, identify underrepresented regions, and guide global content strategy and acquisition.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✔ Yes — Very Strong Business Benefits**
#
# **A. Identify Content Gaps**
#
# - Underrepresented regions like Africa or the Middle East highlight opportunities to:
#
# - Acquire more titles from these regions
#
# - Improve international reach
#
# - Target new subscriber segments
#
# **B. Support Regional Marketing & Localization**
#
# - High contributions from India or Japan indicate:
#
# - Focus on localization, dubbing, and marketing efforts
#
# - Promote region-specific categories (e.g., “Hindi Movies”, “J-Drama”, “Anime”)
#
# **C. Licensing Strategy**
#
# - Strategic partnerships can be formed with:
#
# - US studios for guaranteed viewership
#
# - Indian studios for high-volume content
#
# - Japanese studios to meet anime demand
#
# **D. Expand Audience Diversity**
#
# - Broader country representation increases genres, languages, and cultural variety, driving higher subscriptions and engagement

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Chart 7 - Top 10 Genres
#bar chart
# Convert genres column from string to list
titles['genres'] = titles['genres'].apply(lambda x: eval(x) if isinstance(x, str) else x)

# Explode genre lists
genre_exploded = titles.explode('genres')

# Count top 10 genres
top_genres = genre_exploded['genres'].value_counts().head(10)

# Plot
plt.figure(figsize=(12, 6))
sns.barplot(x=top_genres.index, y=top_genres.values)
plt.title("Top 10 Genres on Amazon Prime", fontsize=16)
plt.xlabel("Genre")
plt.ylabel("Count of Titles")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I Have selected a **bar chart** of the top 10 genres because genres are a key factor influencing:
#
# - Viewer preferences and engagement
#
# - Content recommendations
#
# - Acquisition and licensing strategy
#
# - Marketing campaigns
#
# **Additionally, analyzing cast participation provides insights into:**
#
# - How many cast members typically appear in a title
#
# - Distribution of cast sizes across titles
#
# - Detection of unusually large or small casts
#
# - Production scale and content diversity
#
# **Purpose of the chart:**
#
# - Identify which genres dominate the Amazon Prime library
#
# - Understand the diversity and scale of content, including cast involvement
#
# - Support genre-specific marketing, content promotion, and strategic decisions
#
# This visualization provides a clear overview of the platform’s content focus and production characteristics, helping guide both business and operational strategies.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The insights I found in this chart are:**
#
# - Drama, Comedy, and Action lead the top genres, indicating strong audience demand for mainstream content.
#
# - Family, Thriller, and Romance are also well-represented, catering to diverse viewers.
#
# - Niche genres like Horror, Sci-Fi, and Documentary are present, providing specialized content.
#
# - Cast size analysis shows most titles have small-to-medium casts, while very large casts are rare. This reflects typical production patterns, budget levels, and the prevalence of simple versus ensemble-based storytelling formats.
#
# - Overall, the top 10 genres show a balanced mix of mainstream and niche content, ensuring variety and broad audience appeal.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✔ Yes — Strong Business Benefits**
#
# - **Content Acquisition Strategy:** Focus on popular genres (Drama, Comedy, Action) while adding underrepresented genres to attract niche audiences.
#
# - **Recommendation Optimization:** Suggest titles based on user-preferred genres, highlighting both mainstream and niche content.
#
# - **Marketing & Promotion:** Promote top genres with curated sections (“Top Comedies”, “Best Thrillers”) and niche genres to target specific groups.
#
# - **Audience Retention & Growth** :Balanced genre representation keeps users engaged and encourages exploration of diverse content.
#
# - **Cast Size Insights:**  Understanding cast-size patterns helps with budgeting, talent contract negotiations, predicting production effort, and planning future content strategy. Large-cast content may increase costs, while smaller casts offer efficient, scalable production opportunities.
#
# **4. Are there any insights that lead to negative growth?**
#
# ⚠ Possible Negative Signals
#
# - Over-reliance on popular genres may reduce variety, driving users toward competitors.
#
# - Underrepresented niche genres (Horror, Sci-Fi, Documentary) limit appeal to specialized audiences.
#
# - Very large casts are rare, potentially limiting ensemble-based storytelling formats.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Chart 8 - Distribution of Cast Members per Title
#histogram
# Count cast members for each title (id)
cast_counts = credits.groupby("id")["name"].count().reset_index()
cast_counts.columns = ["id", "cast_count"]

# Plot histogram
plt.figure(figsize=(10, 5))
sns.histplot(cast_counts["cast_count"], bins=30)
plt.title("Distribution of Cast Members per Title", fontsize=16)
plt.xlabel("Number of Cast Members")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a **histogram** of cast members per title because cast size is a critical aspect of production that affects:
#
# - Production scale and complexity
#
# - Budget planning and cost management
#
# - Talent contract negotiations
#
# - Content strategy and storytelling formats
#
# This chart helps me understand how many cast members typically participate in a title. It visualizes the distribution, detects unusually large or small casts, and provides insight into production scale and content diversity.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The insights I found in this chart are:**
#
# - Most titles have small-to-medium cast sizes, while very large casts are rare. This indicates typical production patterns, budget levels, and the prevalence of simple versus ensemble-based storytelling formats on the platform.
#
# - Extremely small casts exist in some titles, suggesting minimalistic productions or focused storytelling formats.
#
# - The distribution provides insight into content diversity, production scale, and resource allocation for different types of titles.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✔ Yes — Valuable Business Benefits**
#
# - **Budgeting & Cost Management:** Large casts increase costs, while smaller casts allow efficient, scalable production.
#
# - **Production & Content Planning:** Understanding cast-size patterns helps predict effort, plan future content, and guide investment in ensemble vs. simpler productions.
#
# - **Talent Strategy:** Supports negotiations and resource allocation.
#
# - **Operational Efficiency:** Optimizes production schedules and resource usage.
#
# **4. Are there any insights that lead to negative growth?**
#
# **⚠ Possible Negative Signals**
#
# - Limited large-cast content: Restricts variety in ensemble-based storytelling.
#
# - Extremely small casts: May reduce appeal for complex, multi-character stories.
#
# - Skewed distribution: Over-reliance on small casts can limit production diversity and audience engagement.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization
# Chart - 9: IMDb Score vs. Release Year
#scatter plot
plt.figure(figsize=(12,6))
sns.scatterplot(x='release_year', y='imdb_score', data=titles, alpha=0.6)
plt.title('IMDb Score vs. Release Year',fontsize=18,weight='bold')
plt.xlabel('Release Year',fontsize=12)
plt.ylabel('IMDb Score',fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a **scatter plot** because it clearly shows the relationship between two continuous variables—IMDb scores and release years. It helps me:
#
# - Identify trends in content quality over time.
#
# - Observe variations in ratings across different years.
#
# - Detect outliers, such as exceptionally high or low-rated titles.
#
# - Understand whether the quality of content has changed over the years.
#
# - This chart is the most suitable for analyzing historical patterns in content quality and supporting strategic decisions for content acquisition, recommendation, and marketing.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights I found in this chart are:
#
# - Recent titles (post-2010) often cluster in the mid-to-high IMDb range, indicating consistent quality in newer content.
#
# - Older titles show more variation, with a mix of high and low ratings, possibly due to limited archival data or changing audience preferences.
#
# - Some outliers with very high or very low scores exist, highlighting exceptional successes or underperforming content.
#
# - Overall, the platform maintains moderate-to-high content quality across years, with a slight trend toward more consistently rated titles in recent years.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✔ Positive Impact**
#
# - These insights help me identify stable content quality trends over time.
#
# - I can focus content acquisition and investment on high-rated titles.
#
# - Promoting top-rated titles can enhance user engagement and retention.
#
# **⚠ Negative Impact**
#
# - Lack of improvement in recent content quality and large variations in scores may indicate inconsistent production standards.
#
# - This could reduce viewer trust and slow subscriber growth if not addressed.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Chart - 10: Distribution of TMDB Popularity (Matplotlib Only)
#histogram
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.hist(titles['tmdb_popularity'], bins=50)
plt.title('Distribution of TMDB Popularity', fontsize=18, weight='bold')
plt.xlabel('TMDB Popularity', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used a **histogram** because it is the most effective way to show how TMDB Popularity values are distributed across all titles. This chart helps visualize whether popularity is concentrated at lower levels or spread out, and it also highlights skewness or extreme high-popularity titles. Since we are analyzing a single numerical column, a histogram is the most suitable chart to understand its overall distribution and audience engagement patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# I used a **histogram** because it is the most effective way to show how TMDB Popularity values are distributed across all titles. This chart helps visualize whether popularity is concentrated at lower levels or spread out, and it also highlights skewness or extreme high-popularity titles. Since we are analyzing a single numerical column, a histogram is the most suitable chart to understand its overall distribution and audience engagement patterns.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
#
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Yes, the insights can create a positive business impact**.
# Understanding that only a few titles drive very high popularity helps the platform focus on the right content for marketing, promotions, and future investments. By identifying these high-performing titles, Prime Video can allocate budgets more efficiently, boost engagement, and improve ROI.
#
# **However, there is also a negative aspect.**
# The distribution shows that most titles have low popularity, indicating uneven audience engagement. This over-dependence on a few hit titles can be risky—if these titles lose relevance or competitors release stronger content, overall platform engagement may drop. It also suggests that a large portion of the catalog may not be contributing significantly to user satisfaction.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code - Calculate Average IMDb Score by Genre
# Use the genre_exploded DataFrame created earlier in Chart 7, where genres are already expanded.
# bar chart
avg_imdb_score_by_genre = genre_exploded.groupby('genres')['imdb_score'].mean().reset_index()

# Get the top 10 genres by average IMDb score (or all, depending on how many you want to visualize)
top_genres_by_score = avg_imdb_score_by_genre.nlargest(10, 'imdb_score')

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='genres', y='imdb_score', data=top_genres_by_score, palette="coolwarm")
plt.title('Average IMDb Score by Genre',fontsize=16,weight='bold')
# The legend is not necessary for a simple bar plot without a 'hue' parameter
# plt.legend(loc=0)
plt.xticks(rotation=45)
plt.xlabel('Genre',fontsize=12)
plt.ylabel('Average IMDb Score',fontsize=12)
plt.show()
# Out:
# /tmp/ipython-input-3024537327.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='genres', y='imdb_score', data=top_genres_by_score, palette="coolwarm")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# I selected a **bar chart** to visualize the average IMDb score by genre because bar charts are ideal for comparing categorical groups against a numerical value. Each genre is a distinct category, and the bar height clearly shows differences in average viewer ratings. This makes it easy to identify which genres consistently perform well and which receive lower audience appreciation. The chart provides an intuitive comparison that supports strategic decisions on content investment, genre prioritization, and platform recommendations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
# The chart shows that certain genres consistently receive higher average IMDb scores, indicating stronger audience appreciation and better content quality in those categories. Genres like **Documentary, Animation, or Adventure** (example based on typical data) tend to have higher ratings, while genres such as **Reality or Talk Shows** may score lower. This suggests that focusing on high-rated genres can improve viewer satisfaction and engagement, while low-rated genres may require content improvement or careful selection.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# **Yes, the insights can create a positive business impact.**
# By identifying genres with higher average IMDb scores, Prime Video can prioritize producing or acquiring content in these categories. This can enhance viewer satisfaction, boost engagement, and improve retention, leading to better ROI on content investment.
#
# **However, there is also a potential negative aspect.**
# Genres with consistently lower IMDb scores indicate weaker audience appreciation. Over-investing in these genres without improving content quality may lead to low engagement and wasted resources, negatively affecting overall platform performance.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization
# Chart - 12: TMDB Popularity vs Content Type
#box plot
plt.figure(figsize=(10,6))
sns.boxplot(x='type', y ='tmdb_popularity', data=titles,palette="coolwarm")
plt.title('TMDB Popularity vs Content Type',fontsize=18,weight='bold')
plt.xlabel('Content Type',fontsize=12)
plt.ylabel('TMDB Popularity', fontsize=12)
plt.show()
# Out:
# /tmp/ipython-input-2428574139.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='type', y ='tmdb_popularity', data=titles,palette="coolwarm")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a **box plot** because it effectively shows the distribution of TMDB Popularity for each content type (Movie vs Show). It highlights the median, spread, and presence of outliers, making it easy to compare audience engagement across categories. This chart helps identify which content type generally receives higher popularity and detects variability or extreme values in viewer interest.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The **box plot** shows the distribution of TMDB Popularity for Movies and TV Shows:
#
# **Movies vs. TV Shows popularity:** One type (usually Movies) may have a higher median popularity, while TV Shows show more variation, with some very popular and some low-popularity titles.
#
# **Outliers indicate highly popular content:** Points far above the box represent exceptionally popular titles that drive overall platform engagement.
#
# **Popularity spreads differ by type:** The range and interquartile spread suggest audience engagement differs between Movies and Shows, highlighting which content type consistently attracts viewers.
#
# **Data informs content strategy:** These insights help prioritize production, acquisition, and promotion for the content type that consistently achieves higher popularity, optimizing viewer engagement and platform ROI.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive impact:**
# The insights help Prime Video understand which content type—Movies or TV Shows—generally attracts more viewers. This allows the platform to prioritize production, acquisition, and marketing strategies for the content type with higher engagement, improving viewer retention, satisfaction, and ROI.
#
# **Potential negative aspect:**
# The wide variability and presence of low-popularity titles indicate that not all content in either category performs well. Over-reliance on high-performing outliers or underperforming content can lead to wasted investment and uneven engagement, which may negatively impact overall platform growth if not carefully managed.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
#line plot
import matplotlib.pyplot as plt

# Filter TV Shows
tv_shows = titles[titles['type'] == 'SHOW']

# Count number of shows per season
season_counts = tv_shows['seasons'].value_counts().sort_index()

plt.figure(figsize=(12,6))
plt.plot(season_counts.index, season_counts.values, marker='o', linestyle='-', color='blue')
plt.title('Distribution of TV Shows by Number of Seasons', fontsize=16, weight='bold')
plt.xlabel('Number of Seasons', fontsize=12)
plt.ylabel('Number of TV Shows', fontsize=12)
plt.xticks(season_counts.index)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a **line plot** to show the distribution of TV shows by number of seasons because it clearly illustrates trends across different season counts. The line connects the counts for each season, making it easy to see which season numbers are most common. Markers highlight exact values, allowing quick comparison, while the overall shape of the line helps identify patterns in TV show production and viewer availability across seasons.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that most TV shows have **fewer seasons**, with a sharp decrease in the number of shows as the season count increases. A small number of shows have many seasons, acting as long-running content that can drive consistent viewer engagement. This indicates that while the majority of shows are short-lived, a few multi-season shows play a key role in attracting and retaining viewers. The trend helps understand production patterns and audience preferences for short vs. long series.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive impact:**
# The insights help Prime Video understand that most TV shows have fewer seasons, while a few long-running shows attract consistent engagement. This allows the platform to prioritize acquiring or producing short, high-quality series for variety, and invest in multi-season shows that retain viewers over time, improving engagement, retention, and ROI.
#
# **Potential negative aspect:**
# The sharp drop in shows with higher season counts indicates over-reliance on a few long-running series. If these hit shows lose popularity or end, viewer engagement could drop significantly. Additionally, producing many short series without ensuring quality may result in low engagement, leading to wasted resources.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
#heatmap
import matplotlib.pyplot as plt
import seaborn as sns

# Compute correlation matrix
corr = titles.select_dtypes(include='number').corr()

# Plot heatmap
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Heatmap of Numerical Variables', fontsize=16, weight='bold')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a **heatmap** because it effectively visualizes the correlations between all numerical variables in the dataset. The color gradient quickly highlights strong positive or negative relationships, while annotations show exact correlation values. This makes it easy to identify which variables are closely related, detect patterns, and guide data-driven decisions for analysis or content strategy.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The **heatmap** shows the strength and direction of relationships between numerical variables. For example, **IMDB score and TMDB score may have a positive correlation,** indicating that highly rated content on one platform tends to be highly rated on the other. Variables like **TMDB popularity and number of IMDb votes may also be positively correlated**, suggesting that more popular titles attract more audience engagement. This helps identify which metrics are closely linked and can guide content investment and marketing strategies.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
#pair plot
import seaborn as sns
import matplotlib.pyplot as plt

# Select key numerical variables for clarity
numerical_variables = ['imdb_score', 'tmdb_score', 'tmdb_popularity', 'imdb_votes']

# Pair plot with hue by content type
sns.pairplot(
    data=titles,
    vars=numerical_variables,
    hue='type',         # Movies vs Shows
    corner=True,        # Show only lower triangle
    diag_kind='kde',    # KDE on diagonal
    plot_kws={'alpha':0.6, 's':40}  # transparency and marker size
)

plt.suptitle('Pair Plot of Key Numerical Variables by Content Type', fontsize=16, weight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a **pair plot** because it visualizes relationships between multiple numerical variables simultaneously. Using **hue='type**' allows us to compare Movies vs TV Shows, while the diagonal KDE plots show the distribution of each variable. This chart helps identify correlations, patterns, and differences between content types in a single, intuitive view.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **IMDb and TMDB scores are positively correlated,** meaning highly rated content on one platform tends to be highly rated on the other.
#
# **TMDB popularity vs IMDb votes shows a positive trend,** indicating that more popular titles attract more votes.
#
# **Movies and TV Shows distributions differ:** some variables (like popularity) show higher variability in one content type.
#
# **Outliers** in votes or popularity highlight extremely popular titles that drive platform engagement.

# %% [markdown]
# #### Chart - 16

# %%
# Violin Plot visualization code
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
sns.violinplot(
    data=titles,
    x='type',          # Movies vs Shows
    y='imdb_score',    # Numerical variable to compare
    palette='Set2',
    inner='quartile'   # Shows median and quartiles
)

plt.title('Distribution of IMDb Scores for Movies vs Shows')
plt.xlabel('Type')
plt.ylabel('IMDb Score')
plt.show()
# Out:
# /tmp/ipython-input-3042711550.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# I picked the **violin plot** because it shows both the distribution and density of a numerical variable (IMDb scores) for different categories (Movies vs Shows). It also highlights **medians, quartiles, and outliers**, providing a detailed comparison between the two types of content. This makes it more informative than a simple box plot or histogram.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Movies generally have a slightly higher median IMDb score than Shows.
#
# - Shows have a wider spread, indicating some very high-rated and very low-rated titles.
#
# - Both types have outliers, showing a few extremely popular or unpopular titles.
#
# - The distribution peaks (thicker areas) indicate where most titles cluster in terms of rating.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:**
#
# - Knowing that Movies generally have higher ratings can help Prime Video prioritize acquiring or promoting high-quality movies.
#
# - Understanding Shows’ wider spread helps identify which shows could be promoted to increase engagement.
#
# **Potential Negative Impact:**
#
# - The presence of low-rated Shows suggests some shows may not attract viewers, which could reduce engagement if not managed properly.
#
# - Relying heavily on low-performing Shows without curation could negatively affect user satisfaction.

# %% [markdown]
# #### Chart - 17

# %%
# Chart - 17 visualization code
#Chart - 17 Content Ratings by Type
#Swarm plot
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
sns.swarmplot(
    data=titles,
    x='age_certification',
    y='imdb_score',
    hue='type',
    palette='Set2',
    alpha=0.7
)
plt.title('Swarm Plot: IMDb Scores by Age Certification and Type')
plt.xlabel('Age Certification')
plt.ylabel('IMDb Score')
plt.legend(title='Type')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 93.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 56.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 29.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 55.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  - I select this **Swarm plot** because it Shows individual data points for Movies and Shows across different age groups.
#
# - Highlights outliers and rating distribution, giving more detail than a simple box plot or bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Movies generally have higher IMDb scores than Shows in most age categories.
#
# - Shows have more spread in ratings, indicating varied quality.
#
# - Some age groups (like PG-13 or R) have highly rated outliers, showing standout titles.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive:** Helps Prime Video identify which content types and age categories perform best, guiding content acquisition and promotion strategies.
#
# **Negative**: Categories with low-rated content may reduce engagement, highlighting areas where investment in quality content is needed.

# %% [markdown]
# #### Chart - 18

# %%
# Chart - 18 visualization code
# chart - 18 Runtime Distribution Strip plot
#strip plot
plt.figure(figsize=(10,6))
sns.stripplot(
    data=titles,
    x='type',
    y='runtime',
    jitter=True,
    palette='Set1',
    alpha=0.6
)
plt.title('Strip Plot: Runtime Distribution by Type')
plt.xlabel('Type')
plt.ylabel('Runtime (minutes)')
plt.show()
# Out:
# /tmp/ipython-input-1414873868.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - I selected **strip plot** and it Shows how runtime varies between Movies and Shows.
#
# - Highlights outliers and patterns clearly.
#
# - Helps compare both categories in a simple visual.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Movies usually have wider runtime variation than Shows.
#
# - Shows cluster around shorter, consistent runtimes.
#
# - A few extreme long-runtime titles stand out as outliers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Helps identify ideal runtime ranges for audience engagement.
#
# - Supports content planning decisions (e.g., episode length).
#
# - Optimizes production strategy by understanding what viewers prefer.

# %% [markdown]
# #### Chart - 19

# %%
# Chart - 19 visualization code
#Chart - 19 Age–Type Distribution
#Stacked Bar Chart
age_type_counts = titles.groupby(['age_certification','type']).size().unstack(fill_value=0)
age_type_counts.plot(kind='bar', stacked=True, figsize=(12,6), colormap='Set3')
plt.title('Stacked Bar: Content Type Distribution by Age Certification')
plt.xlabel('Age Certification')
plt.ylabel('Number of Titles')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - I selected **Stacked Bar Char**t and it Clearly compares Movies vs Shows across different age certifications.
#
# - Shows overall distribution + internal proportion in one view.
#
# - Best for visualizing category vs category comparisons.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Helps identify which age groups contain more movies or shows.
#
# - Shows if content is heavily concentrated in family-friendly, teen, or adult categories.
#
# - Reveals imbalance (e.g., more movies in PG-13, more shows in TV-MA).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Helps platform decide which audience age groups need more content.
#
# - Supports targeted content acquisition (e.g., add more teen-friendly shows if that category is weak).
#
# - Helps marketing focus on high-content age groups for promotions and recommendations.

# %% [markdown]
# #### Chart - 20

# %%
# Chart - 20 visualization code
# Chart - 20 Genre Share Overview
# Genre Distribution Donut Chart

plt.figure(figsize=(10,8))

# Convert genre lists to individual values
genre_list = titles['genres'].dropna().explode()

# Count genre frequency
genre_counts = genre_list.value_counts().head(10)

# Donut plot
plt.pie(
    genre_counts,
    labels=genre_counts.index,
    autopct='%1.1f%%',
    startangle=140,
    wedgeprops={'width':0.4}
)

plt.title('Top 10 Genres – Donut Chart', fontsize=14)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It clearly shows which **genres dominate the platform**, helping identify content imbalance and audience preference trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Shows the **top** **genres** and their **proportion** in the catalog.
#
# - Helps reveal genre diversity or over-concentration.
#
# - Useful for understanding **content strategy gaps**.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Helps Prime Video decide which **genres to produce/acquire more**
# - Supports marketing focus on **high-volume or high-demand genres.**
#
# - Helps identify missing genres → o**pportunity to attract new audiences.**

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on the analysis of the **Amazon Prime Movies and TV Shows dataset**, the following strategies are suggested to optimize content strategy, enhance user engagement, and support strategic growth:
#
# **1. Leverage Movie Dominance while Expanding TV Shows:**
#
# - The dataset shows a strong dominance of movies compared to TV shows. Continue acquiring and promoting high-quality movies, particularly those with high IMDb and TMDB scores.
#
# - Simultaneously, strategically invest in TV shows, especially series with potential for multiple seasons, to cater to binge-watchers and balance the content library.
#
# **2. Promote Highly-Rated Content Across Genres:**
#
# - Utilize genre-specific insights to promote content with high IMDb/TMDB scores but lower popularity, ensuring hidden gems receive visibility.
#
# - Prioritize genres that resonate with audiences and identify underrepresented genres to diversify the library.
#
# **3. Enhance Age-Based Targeting and Compliance:**
#
# - Address missing or ‘Unknown’ age certification data to improve content discoverability, parental controls, and user trust.
#
# - Align content promotion with appropriate age categories for better engagement.
#
# **4. Diversify Production Sources:**
#
# - While the US dominates production, acquire or produce content from emerging markets and international studios to appeal to a wider global audience and enhance library diversity.
#
# **5. Optimize Series Strategy:**
#
# - Analyze engagement metrics for shorter series (1–2 seasons) to determine which formats retain viewers.
#
# - Invest in renewing successful shows or producing longer-form series to increase retention and satisfaction.
#
# **6. Leverage IMDb and TMDB Metrics:**
#
# - The strong correlation between IMDb and TMDB scores indicates these metrics are useful for evaluating content quality.
#
# - Use these alongside viewership metrics, ratings trends, and user feedback for holistic decision-making in content acquisition and promotion.
#
# **7. Improve Content Discovery and Recommendations:**
#
# - The dataset shows skewed popularity distribution with few highly popular titles. Enhance recommendation algorithms to highlight lesser-known but high-quality content.
#
# - Introduce features like personalized suggestions, genre-based curation, and trending content to improve overall engagement and user satisfaction.
#
# **8. Strategic Marketing and Promotions:**
#
# - Focus marketing on high-performing content and niche genres with high engagement potential.
#
# - Promote new acquisitions strategically to maximize visibility and attract new subscribers.
#
# **9. Data-Driven Monitoring:**
#
# - Continuously monitor ratings, popularity, runtime, and user engagement metrics to identify trends and adjust content strategy.
#
# - Use these insights to make timely investment decisions, ensuring that the library stays relevant and competitive.
#
# - Overall Impact: By implementing these strategies, Amazon Prime Video can balance its movie-heavy library with engaging TV shows, improve content discovery, optimize viewer retention, and make data-driven decisions for sustainable growth in the competitive streaming market.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This project analyzed Amazon Prime Video’s movies and TV shows using metrics such as IMDb scores, TMDB popularity, genres, content types, number of seasons, and release years. The analysis revealed that certain genres and content types consistently perform better, while others attract lower engagement. Correlation and pair plots highlighted relationships between features like seasons, episodes, and ratings. Based on these insights, recommendations include focusing on high-performing genres, promoting top-rated content, optimizing content type strategy, and leveraging data-driven personalization. Implementing these strategies can enhance viewer satisfaction, increase engagement, and support sustainable subscriber growth.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
